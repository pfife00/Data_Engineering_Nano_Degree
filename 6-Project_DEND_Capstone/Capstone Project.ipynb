# %% [markdown]
# # Project Title
# ### Data Engineering Capstone Project
#
# #### Project Summary
# --describe your project at a high level--
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
#import libraries
import pandas as pd
import configparser
import boto3
import pandas as pd
import re
import psycopg2

# %% [markdown]
# <h3>2 - Questions</h3>

# %% [markdown]
# <ol>
#     <li>Which cities do immigrants tend to move and where did they come from?</li>
# <li>Does temperature play a role on where people on temporary visas go?</li>
# </ol>

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# Explain what you plan to do in the project in more detail. What data do you use? What is your end solution look like? What tools did you use? etc?
#
# #### Describe and Gather Data
# Describe the data sets you're using. Where did it come from? What type of information is included?

# %% [markdown]
# The data sets used for this project are airport codes, immigration data, us cities demographics data, and temperature data
# <h4>Airport Codes</h4>
# Airport codes may refer to either IATA airport code, a three-letter code which is used in passenger reservation, ticketing and baggage-handling systems, or the ICAO airport code which is a four letter code used by ATC systems and for airports that do not have an IATA airport code. The data was provided by Udacity which was obtained from <a href="https://datahub.io/core/airport-codes#data">Data Hub</a>.
# <h4>Immigration Data</h4>
# The data comes from the US National Tourism and Trade Office and provided by Udacity. A data dictionary is provided within the file I94_SAS_Labels_Descriptions.SAS.
# The data set was taken from <a href="https://travel.trade.gov/research/reports/i94/historical/2016.html">this link</a>.
# The dataset can be previewed from the immigration_data_sample.csv file. The full dataset consists of several SAS files which are located within the
# SAS_data folder.
# <h4>Temperature Data</h4>
# The dataset is provided by <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons BY-NC-SA 4.0 </a>.
# <h4>US Cities Demographics</h4>
# The data comes from <a href="https://public.opendatasoft.com/explore/dataset/us-cities-demographics/export/">OpenSoft</a>. The dataset contains information about the demographics of all US cities and census-designated places with a population greater or equal to 65,000. This data comes from the US Census Bureau's 2015 American Community Survey <a href="https://www.census.gov/data/developers/about/terms-of-service.html">and is referenced in this link. </a>

# %%
#Get AWS credentials
config = configparser.ConfigParser()
config.read('dwh.cfg')
AWS_ACCESS_KEY_ID = config.get('AWS', 'AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = config.get('AWS', 'AWS_SECRET_ACCESS_KEY')
s3 = boto3.resource('s3', aws_access_key_id = AWS_ACCESS_KEY_ID, aws_secret_access_key = AWS_SECRET_ACCESS_KEY)

# %%
# Show all the columns for the datasets
pd.set_option('display.max_columns', 30)

# %% [markdown]
# <h4>Airport Codes</h4>

# %%
#Read airport codes csv and preview the data
data_airport_codes = pd.read_csv('airport-codes_csv.csv')
data_airport_codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %%
#get shape of dataset
data_airport_codes.shape
# Out:
# (55075, 12)

# %% [markdown]
# <h4>Immigration Data</h4>

# %%
#Read immigration data csv and preview the data
data_immigration = pd.read_csv('immigration_data_sample.csv')
data_immigration.head()
# Out:
#    Unnamed: 0      cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  \
# 0     2027561  4084316.0  2016.0     4.0   209.0   209.0     HHW  20566.0
# 1     2171295  4422636.0  2016.0     4.0   582.0   582.0     MCA  20567.0
# 2      589494  1195600.0  2016.0     4.0   148.0   112.0     OGG  20551.0
# 3     2631158  5291768.0  2016.0     4.0   297.0   297.0     LOS  20572.0
# 4     3032257   985523.0  2016.0     4.0   111.0   111.0     CHM  20550.0
#
#    i94mode i94addr  depdate  i94bir  i94visa  count  dtadfile visapost occup  \
# 0      1.0      HI  20573.0    61.0      2.0    1.0  20160422      NaN   NaN
# 1      1.0      TX  20568.0    26.0      2.0    1.0  20160423      MTR   NaN
# 2      1.0      FL  20571.0    76.0      2.0    1.0  20160407      NaN   NaN
# 3      1.0      CA  20581.0    25.0      2.0    1.0  20160428      DOH   NaN
# 4      3.0      NY  20553.0    19.0      2.0    1.0  20160406      NaN   NaN
#
#   entdepa entdepd  entdepu matflag  biryear   dtaddto gender  insnum airline  \
# 0       G       O      NaN       M   1955.0  07202016      F     NaN      JL
# 1       G       R      NaN       M   1990.0  10222016      M     NaN     *GA
# 2       G       O      NaN       M   1940.0  07052016      M     NaN      LH
# 3       G       O      NaN       M   1991.0  10272016      M     NaN      QR
# 4       Z       K      NaN       M   1997.0  07042016      F     NaN     NaN
#
#          admnum  fltno visatype
# 0  5.658267e+10  00782       WT
# 1  9.436200e+10  XBLNG       B2
# 2  5.578047e+10  00464       WT
# 3  9.478970e+10  00739       B2
# 4  4.232257e+10   LAND       WT

# %%
#Read in SAS files
imm_fname = '../../data/18-83510-I94-Data-2016/i94_dec16_sub.sas7bdat'
data_imm_dec = pd.read_sas(imm_fname, 'sas7bdat', encoding="ISO-8859-1")

# %%
#preview the data
data_imm_dec.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0   46.0  2016.0    12.0   129.0   129.0     HOU  20789.0      1.0      TX
# 1   56.0  2016.0    12.0   245.0   245.0     NEW  20789.0      1.0      OH
# 2   67.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      MD
# 3   68.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      FL
# 4   69.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      HI
#
#    depdate  i94bir  i94visa  count  dtadfile visapost occup entdepa entdepd  \
# 0  20802.0    46.0      1.0    1.0  20161201      MDD   NaN       H       O
# 1  20835.0    28.0      3.0    1.0  20161201      BEJ   NaN       U       O
# 2  20794.0    48.0      2.0    1.0  20161201      NAS   NaN       A       D
# 3  20792.0    46.0      2.0    1.0  20161201      NAS   NaN       A       D
# 4  20792.0    48.0      2.0    1.0  20161201      NAS   NaN       A       D
#
#   entdepu matflag  biryear   dtaddto gender insnum airline        admnum  \
# 0     NaN       M   1970.0  05262018      M    NaN      RS  9.755414e+10
# 1     NaN       M   1988.0       D/S      F    NaN      CA  9.062372e+10
# 2     NaN       M   1968.0  06012017      M   5920     NaN  8.010503e+10
# 3     NaN       M   1970.0  06012017      F   5920     NaN  8.010511e+10
# 4     NaN       M   1968.0  06012017      M   5920     NaN  8.010511e+10
#
#   fltno visatype
# 0  7715       E2
# 1   819       F1
# 2   NaN       B2
# 3   NaN       B2
# 4   NaN       B2

# %%
#get shape of dataset
data_imm_dec.shape
# Out:
# (3432990, 28)

# %%
#Read in SAS files
imm_fname = '../../data/18-83510-I94-Data-2016/i94_jul16_sub.sas7bdat'
data_imm_july = pd.read_sas(imm_fname, 'sas7bdat', encoding="ISO-8859-1")

# %%
#preview the data
data_imm_july.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0    1.0  2016.0     7.0   254.0   276.0     LOS  20636.0      1.0      CA
# 1    2.0  2016.0     7.0   140.0   140.0     NYC  20636.0      1.0      NY
# 2    3.0  2016.0     7.0   135.0   135.0     ORL  20636.0      1.0      FL
# 3    4.0  2016.0     7.0   124.0   124.0     TAM  20636.0      1.0      FL
# 4    5.0  2016.0     7.0   130.0   130.0     LOS  20636.0      1.0      CA
#
#    depdate  i94bir  i94visa  count  dtadfile visapost occup entdepa entdepd  \
# 0  20640.0    38.0      2.0    1.0  20160701      NaN   NaN       G       O
# 1  20657.0    45.0      2.0    1.0  20160701      NaN   NaN       G       O
# 2  20657.0    10.0      2.0    1.0  20160701      NaN   NaN       G       O
# 3  20645.0    17.0      2.0    1.0  20160701      NaN   NaN       G       O
# 4  20662.0     1.0      2.0    1.0  20160701      NaN   NaN       G       K
#
#   entdepu matflag  biryear   dtaddto gender insnum airline        admnum  \
# 0     NaN       M   1978.0  09282016      M    NaN      OZ  6.309290e+10
# 1     NaN       M   1971.0  09282016      F    NaN      DL  6.309290e+10
# 2     NaN       M   2006.0  09282016      M    NaN      VS  6.309290e+10
# 3     NaN       M   1999.0  09282016      M    NaN      LH  6.309290e+10
# 4     NaN       M   2015.0  09282016      M    NaN      SU  6.309290e+10
#
#    fltno visatype
# 0  00202       WT
# 1  09858       WT
# 2  00071       WT
# 3  00482       WT
# 4  00106       WT

# %%
#get shape of dataset
data_imm_july.shape
# Out:
# (4265031, 28)

# %% [markdown]
# <h4>Combine Immigration Data Sets</h4>

# %%
#concantenate dataframes
data_imm = pd.concat([data_imm_dec, data_imm_july])

# %%
#reset indices
data_imm = data_imm.reset_index(drop=True)

# %%
data_imm.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0   46.0  2016.0    12.0   129.0   129.0     HOU  20789.0      1.0      TX
# 1   56.0  2016.0    12.0   245.0   245.0     NEW  20789.0      1.0      OH
# 2   67.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      MD
# 3   68.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      FL
# 4   69.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0      HI
#
#    depdate  i94bir  i94visa  count  dtadfile visapost occup entdepa entdepd  \
# 0  20802.0    46.0      1.0    1.0  20161201      MDD   NaN       H       O
# 1  20835.0    28.0      3.0    1.0  20161201      BEJ   NaN       U       O
# 2  20794.0    48.0      2.0    1.0  20161201      NAS   NaN       A       D
# 3  20792.0    46.0      2.0    1.0  20161201      NAS   NaN       A       D
# 4  20792.0    48.0      2.0    1.0  20161201      NAS   NaN       A       D
#
#   entdepu matflag  biryear   dtaddto gender insnum airline        admnum  \
# 0     NaN       M   1970.0  05262018      M    NaN      RS  9.755414e+10
# 1     NaN       M   1988.0       D/S      F    NaN      CA  9.062372e+10
# 2     NaN       M   1968.0  06012017      M   5920     NaN  8.010503e+10
# 3     NaN       M   1970.0  06012017      F   5920     NaN  8.010511e+10
# 4     NaN       M   1968.0  06012017      M   5920     NaN  8.010511e+10
#
#   fltno visatype
# 0  7715       E2
# 1   819       F1
# 2   NaN       B2
# 3   NaN       B2
# 4   NaN       B2

# %%
#how many different types of visas are listed within the dataset?
data_imm['visatype'].nunique()
# Out:
# 17

# %%
#read in immigration data dictionary

with open('I94_SAS_Labels_Descriptions.SAS') as f:
    txt = f.read()
    f.seek(0)
    lines = f.readlines()
comment_lines = [line for line in lines if line.startswith('/*') and line.endswith('*/\n')]

# %%
clpatt = re.compile(r'^/\*\s+(?P<code>.+?)\s+-\s+(?P<description>.+)\s+\*/$')
matches = [clpatt.match(line) for line in comment_lines]
if not all(m is not None for m in matches):
    for i, m in enumerate(matches):
        if m is None:
            print(i)
print(f'CODE{"":16}', 'DESCRIPTION')
for m in matches:
    print(f'{m.group("code"):20}', m.group('description'))
# Out:
# CODE                 DESCRIPTION
# I94YR                4 digit year
# I94MON               Numeric month
# I94CIT & I94RES      This format shows all the valid and invalid codes for processing
# I94PORT              This format shows all the valid and invalid codes for processing
# I94MODE              There are missing values as well as not reported (9)
# I94BIR               Age of Respondent in Years
# COUNT                Used for summary statistics
# DTADFILE             Character Date Field - Date added to I-94 Files - CIC does not use
# VISAPOST             Department of State where where Visa was issued - CIC does not use
# OCCUP                Occupation that will be performed in U.S. - CIC does not use
# ENTDEPA              Arrival Flag - admitted or paroled into the U.S. - CIC does not use
# ENTDEPD              Departure Flag - Departed, lost I-94 or is deceased - CIC does not use
# ENTDEPU              Update Flag - Either apprehended, overstayed, adjusted to perm residence - CIC does not use
# MATFLAG              Match flag - Match of arrival and departure records
# BIRYEAR              4 digit year of birth
# DTADDTO              Character Date Field - Date to which admitted to U.S. (allowed to stay until) - CIC does not use
# GENDER               Non-immigrant sex
# INSNUM               INS number
# AIRLINE              Airline used to arrive in U.S.
# ADMNUM               Admission Number
# FLTNO                Flight number of Airline used to arrive in U.S.
# VISATYPE             Class of admission legally admitting the non-immigrant to temporarily stay in U.S.

# %% [markdown]
# <h4>Temperature Data</h4>

# %%
#Read temperature dataset from link provided by Udacity
fname = '../../data2/GlobalLandTemperaturesByCity.csv'
data_temp = pd.read_csv(fname)
data_temp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
#get shape of dataset
data_temp.shape
# Out:
# (8599212, 7)

# %% [markdown]
# <h4>US Cities Demographics</h4>

# %%
#Read immigration data csv and preview the data
data_demo = pd.read_csv('us-cities-demographics.csv', sep=';')
data_demo.head()
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0            41862.0             82463              1562.0       30908.0
# 1            49500.0             93629              4147.0       32935.0
# 2            46799.0             84839              4819.0        8229.0
# 3            87105.0            175232              5821.0       33878.0
# 4           143873.0            281913              5829.0       86253.0
#
#    Average Household Size State Code                       Race  Count
# 0                    2.60         MD         Hispanic or Latino  25924
# 1                    2.39         MA                      White  58723
# 2                    2.58         AL                      Asian   4759
# 3                    3.18         CA  Black or African-American  24437
# 4                    2.73         NJ                      White  76402

# %%
#get shape of dataset
data_demo.shape
# Out:
# (2891, 12)

# %%
# from pyspark.sql import SparkSession
# spark = SparkSession.builder.\
# config("spark.jars.packages","saurfang:spark-sas7bdat:2.0.0-s_2.11")\
# .enableHiveSupport().getOrCreate()
# df_spark =spark.read.format('com.github.saurfang.sas.spark').load('../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat')

# %%
# #write to parquet
# df_spark.write.parquet("sas_data")
# df_spark=spark.read.parquet("sas_data")

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %%
# Performing cleaning tasks here

# %% [markdown]
# <h4>Clean Combined Immigration Data</h4>

# %% [markdown]
# <h4>Drop Unecsasry Columns</h4>
# The combined immigatation dataset contains several columns with values of NaN. The first step is to identify those columns and if those columns are not needed, remove the columms.
# <ul>
#     <li>occup - occupation that will be performed in the US. This column does not seem relevant to my project so I removed the column</li>
#     <li>entdepu - Departure Flag - Departed, lost I-94 or is deceased. This column does not seem relevant to my project so I removed the column</li>
#     <li>insnum - INS number </li>
#     </ul>

# %%
#columns to be dropped
col_drop = ['occup', 'entdepu', 'insnum']

# %%
data_imm.drop(axis=1, columns=col_drop)
# Out:
#              cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  \
# 0             46.0  2016.0    12.0   129.0   129.0     HOU  20789.0      1.0
# 1             56.0  2016.0    12.0   245.0   245.0     NEW  20789.0      1.0
# 2             67.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 3             68.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 4             69.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 5             70.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 6             71.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 7             72.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 8             73.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 9             74.0  2016.0    12.0   512.0   512.0     XXX  20789.0      2.0
# 10            75.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 11            76.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 12            77.0  2016.0    12.0   512.0   512.0     PEV  20789.0      9.0
# 13            78.0  2016.0    12.0   512.0   512.0     PEV  20789.0      9.0
# 14           106.0  2016.0    12.0   104.0   104.0     CHM  20789.0      9.0
# 15           107.0  2016.0    12.0   104.0   104.0     CHM  20789.0      9.0
# 16           108.0  2016.0    12.0   148.0   112.0     CHM  20789.0      9.0
# 17           159.0  2016.0    12.0   135.0   135.0     HOU  20789.0      2.0
# 18           166.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
# 19           167.0  2016.0    12.0   512.0   512.0     PEV  20789.0      9.0
# 20           168.0  2016.0    12.0   512.0   512.0     PEV  20789.0      9.0
# 21           169.0  2016.0    12.0   512.0   512.0     PEV  20789.0      9.0
# 22           170.0  2016.0    12.0   512.0   512.0     PEV  20789.0      2.0
#
# 3            FL  20792.0    46.0      2.0    1.0  20161201      NAS       A
# 4            HI  20792.0    48.0      2.0    1.0  20161201      NAS       A
# 5            FL  20792.0     9.0      2.0    1.0  20161201      NAS       A
# 6            VA  20792.0    34.0      2.0    1.0  20161201      NAS       A
# 7            NY  20792.0    69.0      2.0    1.0  20161201      NAS       A
# 8            NY  20794.0    66.0      2.0    1.0  20161201      NAS       A
# 9            DC  20794.0    56.0      2.0    1.0  20161201      NAS       A
# 10           VA  20794.0     6.0      2.0    1.0  20161201      NAS       A
# 11           VA  20794.0    38.0      2.0    1.0  20161201      NAS       A
# 12           NY  20794.0    40.0      2.0    1.0  20161201      NAS       A
# 13           FL  20792.0    28.0      2.0    1.0  20161201      NaN       A
# 14           NJ      NaN    26.0      2.0    1.0  20161201      NaN       A
# 15           NJ      NaN    26.0      2.0    1.0  20161201      NaN       A
# 16           FL      NaN    26.0      2.0    1.0  20161201      NaN       A
# 17           TX  20907.0    65.0      1.0    1.0  20161201      LND       U
# 18           FL  20792.0    37.0      2.0    1.0  20161201      NAS       A
# 19           HI  20792.0    24.0      2.0    1.0  20161201      NAS       A
# 20           FL      NaN    53.0      2.0    1.0  20161201      NAS       A
# 21           FL  20792.0    53.0      2.0    1.0  20161201      NAS       A
# 22           FL  20794.0    35.0      2.0    1.0  20161201      NaN       A
# 23           NY      NaN    22.0      2.0    1.0  20161201      NaN       A
# 24           DC      NaN    49.0      2.0    1.0  20161201      NaN       A
# 25           MD  20792.0    28.0      2.0    1.0  20161201      NAS       A
# 26           FL      NaN    40.0      2.0    1.0  20161201      NAS       A
# 27           FL      NaN    44.0      2.0    1.0  20161201      NAS       A
# 28           NY  20794.0    35.0      2.0    1.0  20161201      NAS       A
# 29           NY  20794.0    30.0      2.0    1.0  20161201      NAS       A
# ...         ...      ...     ...      ...    ...       ...      ...     ...
# 7697991      FL  20657.0    32.0      1.0    1.0  20160720      TRT       Z
# 7697992     NaN  20660.0    71.0      2.0    1.0  20160708      BLG       Z
# 7697993      NY  20638.0    44.0      2.0    1.0  20160701      TRT       Z
# 7697994      NY  20638.0    41.0      2.0    1.0  20160704      NaN       Z
# 7697995      OH  20638.0    61.0      2.0    1.0  20160702      BLG       Z
# 7697996      OH  20640.0    48.0      2.0    1.0  20160706      NaN       Z
# 7697997      NY  20679.0    69.0      2.0    1.0  20160730      BLG       Z
# 7697998      IL  20648.0    29.0      2.0    1.0  20160702      BLG       Z
# 7697999      NY  20655.0    45.0      2.0    1.0  20160719      BLG       Z
# 7698000      MI      NaN    48.0      2.0    1.0  20160717      TRT       Z
# 7698001      TX  20652.0    58.0      1.0    1.0  20160711      BLG       Z
# 7698002      KY  20663.0    30.0      1.0    1.0  20160728      NaN       Z
# 7698003      MI      NaN    27.0      2.0    1.0  20160725      BLG       Z
# 7698004      IL  20667.0    47.0      2.0    1.0  20160801      NaN       Z
# 7698005      IL  20667.0    45.0      2.0    1.0  20160801      NaN       Z
# 7698006      MT  20666.0     6.0      2.0    1.0  20160730      CLG       Z
# 7698007      MT  20666.0    33.0      2.0    1.0  20160730      CLG       Z
# 7698008      WA  20659.0    28.0      2.0    1.0  20160725      NaN       Z
# 7698009      MA      NaN    32.0      1.0    1.0  20160704      BLG       Z
# 7698010      CA      NaN    23.0      2.0    1.0  20160722      MEX       Z
# 7698011      CA  20648.0    49.0      1.0    1.0  20160710      VAC       Z
# 7698012      CA  20656.0    43.0      1.0    1.0  20160722      NaN       Z
# 7698013      WA  20659.0    31.0      2.0    1.0  20160716      CLG       Z
# 7698014      CA  20644.0    42.0      1.0    1.0  20160702      BLG       Z
# 7698015      MD  20638.0    30.0      2.0    1.0  20160701      OTT       Z
# 7698016      NJ  20644.0    65.0      2.0    1.0  20160709      NaN       Z
# 7698017      NJ  20644.0    70.0      2.0    1.0  20160703      BLG       Z
# 7698018      MD  20690.0    26.0      2.0    1.0  20160705      NaN       Z
# 7698019      MD  20690.0     9.0      2.0    1.0  20160705      NaN       Z
# 7698020      NY  20655.0    60.0      2.0    1.0  20160712      NaN       Z
#
#         entdepd matflag  biryear   dtaddto gender airline        admnum  \
# 0             O       M   1970.0  05262018      M      RS  9.755414e+10
# 1             O       M   1988.0       D/S      F      CA  9.062372e+10
# 2             D       M   1968.0  06012017      M     NaN  8.010503e+10
# 3             D       M   1970.0  06012017      F     NaN  8.010511e+10
# 4             D       M   1968.0  06012017      M     NaN  8.010511e+10
# 5             D       M   2007.0  06012017      F     NaN  8.010511e+10
# 6             D       M   1982.0  06012017      F     NaN  8.010515e+10
# 7             D       M   1947.0  06012017      F     NaN  8.010515e+10
# 8             D       M   1950.0  06012017      F     NaN  8.010516e+10
# 9             D       M   1960.0  06012017      M     NaN  8.010516e+10
# 10            D       M   2010.0  06012017      M     NaN  8.010519e+10
# 11            D       M   1978.0  06012017      U     NaN  8.010519e+10
# 12            D       M   1976.0  06012017      M     NaN  8.010519e+10
# 13            D       M   1988.0  06012017      F     NaN  8.010522e+10
# 14          NaN     NaN   1990.0  02282017      F     NaN  8.653007e+10
# 15          NaN     NaN   1990.0  02282017      M     NaN  8.653007e+10
# 16            W       M   1990.0  02282017      F     NaN  8.653007e+10
# 17            O       M   1951.0  03312018      M     G1A  9.247095e+10
# 18            D       M   1979.0  06012017      F     NaN  8.010522e+10
# 19            D       M   1992.0  06012017      F     NaN  8.010528e+10
# 20          NaN     NaN   1963.0  06012017      F     NaN  8.010529e+10
# 21            D       M   1963.0  06012017      F     NaN  8.010529e+10
# 22            D       M   1981.0  06012017      M     NaN  8.010529e+10
# 23          NaN     NaN   1994.0  06012017      F     NaN  8.010529e+10
# 24          NaN     NaN   1967.0  06012017      F     NaN  8.010530e+10
# 25            D       M   1988.0  06012017      F     NaN  8.010530e+10
# 26            W       M   1976.0  06012017      M     NaN  8.010530e+10
# 27          NaN     NaN   1972.0  06012017      F     NaN  8.010530e+10
# 28            D       M   1981.0  06012017      M     NaN  8.010531e+10
# 29            D       M   1986.0  06012017      F     NaN  8.010531e+10
# ...         ...     ...      ...       ...    ...     ...           ...
# 7697991       K       M   1984.0  01192017      M     NaN  1.738593e+10
# 7697992       K       M   1945.0  12172016      F     NaN  1.350624e+09
# 7697993       K       M   1972.0  12312016      M     NaN  1.603680e+09
# 7697994       K       M   1975.0  12312016      M     NaN  1.603719e+09
# 7697995       K       M   1955.0  01012017      M     NaN  1.621332e+09
# 7697996       K       M   1968.0  01012017      F     NaN  1.627689e+09
# 7697997       K       M   1947.0  01292017      F     NaN  4.024316e+09
# 7697998       K       M   1987.0  01012017      F     NaN  1.562864e+10
# 7697999       K       M   1971.0  01182017      M     NaN  1.735991e+10
# 7698000     NaN     NaN   1968.0  09042016      F     NaN  8.980118e+10
# 7698001       K       M   1958.0  07102017      M     NaN  1.873886e+09
# 7698002       K       M   1986.0  01242017      F     NaN  3.153832e+09
# 7698003     NaN     NaN   1989.0  01242017      F     NaN  3.036808e+09
# 7698004       K       M   1969.0  01282017      M     NaN  3.848888e+09
# 7698005       K       M   1971.0  01282017      F     NaN  3.849017e+09
# 7698006       K       M   2010.0  01292017      M     NaN  4.023657e+09
# 7698007       K       M   1983.0  01292017      F     NaN  4.023998e+09
# 7698008       K       M   1988.0  01212017      M     NaN  2.579602e+09
# 7698009     NaN     NaN   1984.0  04092018      F     NaN  9.322484e+10
# 7698010     NaN     NaN   1993.0  01212017      F     NaN  2.535675e+09
# 7698011       K       M   1967.0  01082017      M     NaN  1.840969e+09
# 7698012       K       M   1973.0  01152017      M     NaN  1.973318e+09
# 7698013       K       M   1985.0  01152017      F     NaN  1.706325e+10
# 7698014       O       M   1974.0  12162016      M     NaN  9.933939e+10
# 7698015       K       M   1986.0  12312016      F     NaN  1.586481e+09
# 7698016       K       M   1951.0  01022017      F     NaN  1.636851e+09
# 7698017       K       M   1946.0  01022017      M     NaN  1.636906e+09
# 7698018       O       M   1990.0  12072016      F     NaN  1.165249e+09
# 7698019       O       M   2007.0  12072016      F     NaN  1.166088e+09
# 7698020       O       M   1956.0  12142016      M     NaN  9.915644e+10
#
#          fltno visatype
# 0         7715       E2
# 1          819       F1
# 2          NaN       B2
# 3          NaN       B2
# 4          NaN       B2
# 5          NaN       B2
# 6          NaN       B2
# 7          NaN       B2
# 8          NaN       B2
# 9          NaN       B2
# 10         NaN       B2
# 11         NaN       B2
# 12         NaN       B2
# 13         NaN       B2
# 14         NaN       WT
# 15         NaN       WT
# 16         NaN       WT
# 17       7291A       E2
# 18         NaN       B2
# 19         NaN       B2
# 20         NaN       B2
# 21         NaN       B2
# 22         NaN       B2
# 23         NaN       B2
# 24         NaN       B2
# 25         NaN       B2
# 26         NaN       B2
# 27         NaN       B2
# 28         NaN       B2
# 29         NaN       B2
# ...        ...      ...
# 7697991   LAND       B1
# 7697992   LAND       B2
# 7697993   LAND       B2
# 7697994    NaN       B2
# 7697995   LAND       B2
# 7697996    NaN       B2
# 7697997   LAND       B2
# 7697998   LAND       B2
# 7697999   LAND       B2
# 7698000   LAND       B2
# 7698001   LAND       B1
# 7698002    NaN       B1
# 7698003   LAND       B2
# 7698004    NaN       B2
# 7698005    NaN       B2
# 7698006   LAND       B2
# 7698007   LAND       B2
# 7698008    NaN       B2
# 7698009   LAND       E2
# 7698010   LAND       B2
# 7698011   LAND       B1
# 7698012    NaN       B1
# 7698013   LAND       B2
# 7698014  00072       B1
# 7698015   LAND       B2
# 7698016    NaN       B2
# 7698017   LAND       B2
# 7698018   LAND       B2
# 7698019   LAND       B2
# 7698020   LAND       B2
#
# [7698021 rows x 25 columns]

# %% [markdown]
# <h4>Clean Airport Codes</h4>

# %% [markdown]
# <h4>Drop Unnecessary Columns</h4>
# The airport codes dataset contains one column with several NaNs. The first step is to identify those columns and if those columns are not needed, remove the columms.
# <ul>
#     <li>local_code - local airport code. Column is not needed for my dataset</li>
#     <li>gps_code - GPS codes</li>
#     </ul>

# %%
#columns to be dropped
col_drop = ['local_code', 'gps_code']

# %%
data_airport_codes.drop(axis=1, columns=col_drop)
# Out:
#          ident            type                                      name  \
# 0          00A        heliport                         Total Rf Heliport
# 1         00AA   small_airport                      Aero B Ranch Airport
# 2         00AK   small_airport                              Lowell Field
# 3         00AL   small_airport                              Epps Airpark
# 4         00AR          closed        Newport Hospital & Clinic Heliport
# 5         00AS   small_airport                            Fulton Airport
# 6         00AZ   small_airport                            Cordes Airport
# 7         00CA   small_airport                   Goldstone /Gts/ Airport
# 8         00CL   small_airport                       Williams Ag Airport
# 9         00CN        heliport           Kitchen Creek Helibase Heliport
# 10        00CO          closed                                Cass Field
# 11        00FA   small_airport                       Grass Patch Airport
# 12        00FD        heliport                        Ringhaver Heliport
# 13        00FL   small_airport                         River Oak Airport
# 14        00GA   small_airport                          Lt World Airport
# 15        00GE        heliport                          Caffrey Heliport
# 16        00HI        heliport                        Kaupulehu Heliport
# 17        00ID   small_airport                      Delta Shores Airport
# 18        00IG   small_airport                             Goltl Airport
# 19        00II        heliport        Bailey Generation Station Heliport
# 20        00IL   small_airport                            Hammer Airport
# 21        00IN        heliport           St Mary Medical Center Heliport
# 22        00IS   small_airport         Hayenga's Cant Find Farms Airport
# 23        00KS   small_airport                       Hayden Farm Airport
# 24        00KY   small_airport                     Robbins Roost Airport
# 25        00LA        heliport         Shell Chemical East Site Heliport
# 26        00LL        heliport                Ac & R Components Heliport
# 27        00LS   small_airport                           Lejeune Airport
# 28        00MD   small_airport                              Slater Field
# 29        00MI        heliport                     Dow Chemical Heliport
# ...        ...             ...                                       ...
# 55045     ZYAS  medium_airport                           Anshan Air Base
# 55046     ZYCC  medium_airport                           Longjia Airport
# 55047     ZYCH  medium_airport                          Changhai Airport
# 55048     ZYCY  medium_airport                          Chaoyang Airport
# 55049     ZYDU  medium_airport                  Wudalianchi Dedu Airport
# 55050     ZYFX   small_airport                             Fuxin Airport
# 55051     ZYFY  medium_airport                             Dongji Aiport
# 55052     ZYHB   large_airport                           Taiping Airport
# 55053     ZYHE  medium_airport                             Heihe Airport
# 55054     ZYJL   small_airport                             Jilin Airport
# 55055     ZYJM  medium_airport                           Jiamusi Airport
# 55056     ZYJS  medium_airport                      Jiansanjiang Airport
# 55057     ZYJX  medium_airport                    Jixi Xingkaihu Airport
# 55058     ZYJZ  medium_airport                           Jinzhou Airport
# 55059     ZYLD  medium_airport                             Lindu Airport
# 55060     ZYLS  medium_airport                      Yushu Batang Airport
# 55061     ZYMD  medium_airport  Mudanjiang Hailang International Airport
# 55062     ZYMH  medium_airport                           Gu-Lian Airport
# 55063     ZYQQ  medium_airport                  Qiqihar Sanjiazi Airport
# 55064     ZYSQ  medium_airport                 Songyuan Chaganhu Airport
# 55065     ZYTH   small_airport                              Tahe Airport
# 55066     ZYTL   large_airport                        Zhoushuizi Airport
# 55067     ZYTN  medium_airport                 Tonghua Sanyuanpu Airport
# 55068     ZYTX   large_airport                           Taoxian Airport
# 55069     ZYYJ  medium_airport               Yanji Chaoyangchuan Airport
# 55070     ZYYK  medium_airport                     Yingkou Lanqi Airport
# 55071     ZYYY  medium_airport                   Shenyang Dongta Airport
# 55072  ZZ-0001        heliport                           Sealand Helipad
# 55073  ZZ-0002   small_airport                 Glorioso Islands Airstrip
# 55074     ZZZZ   small_airport                   Satsuma IÅjima Airport
#
#        elevation_ft continent iso_country iso_region  \
# 0              11.0       NaN          US      US-PA
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 9            3350.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 12             25.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 15            957.0       NaN          US      US-GA
# 16             43.0       NaN          US      US-HI
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 19            600.0       NaN          US      US-IN
# 20            840.0       NaN          US      US-IL
# 21            634.0       NaN          US      US-IN
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 25             15.0       NaN          US      US-LA
# 26            600.0       NaN          US      US-IL
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 29            588.0       NaN          US      US-MI
# ...             ...       ...         ...        ...
# 55045           NaN        AS          CN      CN-21
# 55046         706.0        AS          CN      CN-22
# 55047          80.0        AS          CN      CN-21
# 55048         568.0        AS          CN      CN-21
# 55049         984.0        AS          CN      CN-23
# 55050         548.0        AS          CN      CN-21
# 55051           NaN        AS          CN      CN-23
# 55052         457.0        AS          CN      CN-23
# 55053        8530.0        AS          CN      CN-23
# 55054           NaN        AS          CN      CN-22
# 55055         262.0        AS          CN      CN-23
# 55056           NaN        AS          CN      CN-23
# 55057         760.0        AS          CN      CN-23
# 55058           NaN        AS          CN      CN-21
# 55059         791.0        AS          CN      CN-23
# 55060       12816.0        AS          CN      CN-63
# 55061         883.0        AS          CN      CN-23
# 55062        1836.0        AS          CN      CN-23
# 55063         477.0        AS          CN      CN-23
# 55064         459.0        AS          CN      CN-22
# 55065        1240.0        AS          CN      CN-23
# 55066         107.0        AS          CN      CN-21
# 55067        1200.0        AS          CN      CN-22
# 55068         198.0        AS          CN      CN-21
# 55069         624.0        AS          CN      CN-22
# 55070           0.0        AS          CN      CN-21
# 55071           NaN        AS          CN      CN-21
# 55072          40.0        EU          GB     GB-ENG
# 55073          11.0        AF          TF     TF-U-A
# 55074         338.0        AS          JP      JP-46
#
#                                municipality iata_code  \
# 0                                  Bensalem       NaN
# 1                                     Leoti       NaN
# 2                              Anchor Point       NaN
# 3                                   Harvest       NaN
# 4                                   Newport       NaN
# 5                                      Alex       NaN
# 6                                    Cordes       NaN
# 7                                   Barstow       NaN
# 8                                     Biggs       NaN
# 9                               Pine Valley       NaN
# 10                               Briggsdale       NaN
# 11                                 Bushnell       NaN
# 12                                Riverview       NaN
# 13                               Okeechobee       NaN
# 14                                 Lithonia       NaN
# 15                                    Hiram       NaN
# 16                              Kailua/Kona       NaN
# 17                               Clark Fork       NaN
# 18                                 McDonald       NaN
# 19                               Chesterton       NaN
# 20                                     Polo       NaN
# 21                                   Hobart       NaN
# 22                                    Kings       NaN
# 23                                  Gardner       NaN
# 24                                 Stanford       NaN
# 25                                 Gonzales       NaN
# 26                                  Chatham       NaN
# 27                                Esterwood       NaN
# 28                             Federalsburg       NaN
# 29                                Ludington       NaN
# ...                                     ...       ...
# 55045                                Anshan       AOG
# 55046                             Changchun       CGQ
# 55047                              Changhai       CNI
# 55048                              Chaoyang       CHG
# 55049                           Wudalianchi       DTU
# 55050                                 Fuxin       NaN
# 55051                                Fuyuan       FYJ
# 55052                                Harbin       HRB
# 55053                                 Heihe       HEK
# 55054                                 Jilin       JIL
# 55055                               Jiamusi       JMU
# 55056                          Jiansanjiang       JSJ
# 55057                                  Jixi       JXA
# 55058                               Jinzhou       JNZ
# 55059                                Yichun       LDS
# 55060                                 Yushu       YUS
# 55061                            Mudanjiang       MDG
# 55062                                  Mohe       OHE
# 55063                               Qiqihar       NDG
# 55064  Qian Gorlos Mongol Autonomous County       YSQ
# 55065                                  Tahe       NaN
# 55066                                Dalian       DLC
# 55067                               Tonghua       TNH
# 55068                              Shenyang       SHE
# 55069                                 Yanji       YNJ
# 55070                               Yingkou       YKH
# 55071                              Shenyang       NaN
# 55072                               Sealand       NaN
# 55073                      Grande Glorieuse       NaN
# 55074                          Mishima-Mura       NaN
#
#                                    coordinates
# 0           -74.93360137939453, 40.07080078125
# 1                       -101.473911, 38.704022
# 2                  -151.695999146, 59.94919968
# 3        -86.77030181884766, 34.86479949951172
# 4                          -91.254898, 35.6087
# 5                      -97.8180194, 34.9428028
# 6      -112.16500091552734, 34.305599212646484
# 7           -116.888000488, 35.350498199499995
# 8                       -121.763427, 39.427188
# 9                     -116.4597417, 32.7273736
# 10                      -104.344002, 40.622202
# 11       -82.21900177001953, 28.64550018310547
# 12      -82.34539794921875, 28.846599578857422
# 13      -80.96920013427734, 27.230899810791016
# 14       -84.06829833984375, 33.76750183105469
# 15       -84.73390197753906, 33.88420104980469
# 16                      -155.980233, 19.832715
# 17     -116.21399688720703, 48.145301818847656
# 18                      -101.395994, 39.724028
# 19        -87.122802734375, 41.644500732421875
# 20        -89.5604019165039, 41.97840118408203
# 21        -87.2605972290039, 41.51139831542969
# 22        -89.1229019165039, 40.02560043334961
# 23       -94.93049621582031, 38.72779846191406
# 24      -84.61969757080078, 37.409400939941406
# 25                       -90.980833, 30.191944
# 26       -89.70559692382812, 39.66529846191406
# 27       -92.42939758300781, 30.13629913330078
# 28       -75.75379943847656, 38.75709915161133
# 29       -86.41670227050781, 43.94940185546875
# ...                                        ...
# 55045                    122.853996, 41.105301
# 55046             125.684997559, 43.9962005615
# 55047             122.666944444, 39.2666666667
# 55048                    120.434998, 41.538101
# 55049                          126.133, 48.445
# 55050                    121.718122, 42.069014
# 55051                    134.366447, 48.199494
# 55052                 126.25, 45.6234016418457
# 55053             127.308883667, 50.1716209371
# 55054                    126.396004, 44.002201
# 55055         130.464996338, 46.84339904789999
# 55056                        132.660278, 47.11
# 55057                          131.193, 45.293
# 55058    121.06199645996094, 41.10139846801758
# 55059                129.019125, 47.7520555556
# 55060        97.0363888889, 32.836388888900004
# 55061             129.569000244, 44.5241012573
# 55062               122.43, 52.912777777799995
# 55063   123.91799926757812, 47.239601135253906
# 55064                    124.550178, 44.938114
# 55065             124.720222222, 52.2244444444
# 55066     121.53900146484375, 38.9656982421875
# 55067             125.703333333, 42.2538888889
# 55068   123.48300170898438, 41.639801025390625
# 55069             129.451004028, 42.8828010559
# 55070                      122.3586, 40.542524
# 55071   123.49600219726562, 41.784400939941406
# 55072                        1.4825, 51.894444
# 55073  47.296388888900005, -11.584277777799999
# 55074                    130.270556, 30.784722
#
# [55075 rows x 10 columns]

# %% [markdown]
# <h4>Clean Temperature Data</h4>

# %%
data_temp
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# 5        1744-04-01               5.788                          3.624
# 6        1744-05-01              10.644                          1.283
# 7        1744-06-01              14.051                          1.347
# 8        1744-07-01              16.082                          1.396
# 9        1744-08-01                 NaN                            NaN
# 10       1744-09-01              12.781                          1.454
# 11       1744-10-01               7.950                          1.630
# 12       1744-11-01               4.639                          1.302
# 13       1744-12-01               0.122                          1.756
# 14       1745-01-01              -1.333                          1.642
# 15       1745-02-01              -2.732                          1.358
# 16       1745-03-01               0.129                          1.088
# 17       1745-04-01               4.042                          1.138
# 18       1745-05-01                 NaN                            NaN
# 19       1745-06-01                 NaN                            NaN
# 20       1745-07-01                 NaN                            NaN
# 21       1745-08-01                 NaN                            NaN
# 22       1745-09-01                 NaN                            NaN
# 23       1745-10-01                 NaN                            NaN
# 24       1745-11-01                 NaN                            NaN
# 25       1745-12-01                 NaN                            NaN
# 26       1746-01-01                 NaN                            NaN
# 27       1746-02-01                 NaN                            NaN
# 28       1746-03-01                 NaN                            NaN
# 29       1746-04-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599182  2011-04-01              12.554                          0.153
# 8599183  2011-05-01              14.066                          0.149
# 8599184  2011-06-01              16.273                          0.267
# 8599185  2011-07-01              16.020                          0.179
# 8599186  2011-08-01              16.975                          0.139
# 8599187  2011-09-01              15.788                          0.109
# 8599188  2011-10-01              11.337                          0.221
# 8599189  2011-11-01               6.990                          0.097
# 8599190  2011-12-01               5.722                          0.261
# 8599191  2012-01-01               4.348                          0.293
# 8599192  2012-02-01               0.376                          0.290
# 8599193  2012-03-01               7.863                          0.135
# 8599194  2012-04-01               8.101                          0.168
# 8599195  2012-05-01              14.169                          0.191
# 8599196  2012-06-01              14.702                          0.342
# 8599197  2012-07-01              17.329                          0.287
# 8599198  2012-08-01              18.588                          0.224
# 8599199  2012-09-01              14.333                          0.207
# 8599200  2012-10-01              10.358                          0.208
# 8599201  2012-11-01               6.469                          0.189
# 8599202  2012-12-01               4.303                          0.341
# 8599203  2013-01-01               1.479                          0.217
# 8599204  2013-02-01               1.559                          0.304
# 8599205  2013-03-01               2.253                          0.267
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# 1         Århus      Denmark   57.05N    10.33E
# 2         Århus      Denmark   57.05N    10.33E
# 3         Århus      Denmark   57.05N    10.33E
# 4         Århus      Denmark   57.05N    10.33E
# 5         Århus      Denmark   57.05N    10.33E
# 6         Århus      Denmark   57.05N    10.33E
# 7         Århus      Denmark   57.05N    10.33E
# 8         Århus      Denmark   57.05N    10.33E
# 9         Århus      Denmark   57.05N    10.33E
# 10        Århus      Denmark   57.05N    10.33E
# 11        Århus      Denmark   57.05N    10.33E
# 12        Århus      Denmark   57.05N    10.33E
# 13        Århus      Denmark   57.05N    10.33E
# 14        Århus      Denmark   57.05N    10.33E
# 15        Århus      Denmark   57.05N    10.33E
# 16        Århus      Denmark   57.05N    10.33E
# 17        Århus      Denmark   57.05N    10.33E
# 18        Århus      Denmark   57.05N    10.33E
# 19        Århus      Denmark   57.05N    10.33E
# 20        Århus      Denmark   57.05N    10.33E
# 21        Århus      Denmark   57.05N    10.33E
# 22        Århus      Denmark   57.05N    10.33E
# 23        Århus      Denmark   57.05N    10.33E
# 24        Århus      Denmark   57.05N    10.33E
# 25        Århus      Denmark   57.05N    10.33E
# 26        Århus      Denmark   57.05N    10.33E
# 27        Århus      Denmark   57.05N    10.33E
# 28        Århus      Denmark   57.05N    10.33E
# 29        Århus      Denmark   57.05N    10.33E
# 6      11592
# 7      32716
# 8       2583
# 9      11060
# 10      5822
# 11       998
# 12    122721
# 13     65162
# 14      8791
# 15     50169
# 16    208863
# 17      1253
# 18     27089
# 19     55847
# 20     22304
# 21     70303
# 22       323
# 23     49181
# 24     29159
# 25     12653
# 26     23355
# 27     33630
# 28     44786
# 29      2205
# ...      ...
# 2861    4722
# 2862   24673
# 2863   19698
# 2864   31386
# 2865    1905
# 2866    3970
# 2867    2444
# 2868     903
# 2869    1065
# 2870   10035
# 2871    3697
# 2872   23736
# 2873   77178
# 2874   30807
# 2875  168057
# 2876   84892
# 2877    6631
# 2878    8746
# 2879    9151
# 2880   14449
# 2881   42870
# 2882     779
# 2883  404868
# 2884    9446
# 2885   53727
# 2886   19834
# 2887     983
# 2888  553665
# 2889     374
# 2890   90896
#
# [2891 rows x 12 columns]

# %% [markdown]
# First we want to ensure that the number of males plus number of females adds up to total population.
# Next we want to ensure that the number of foreign born residents and veteran residents is less than the total population

# %%
i=0
for index, row in data_demo.iterrows():
    if(row['Male Population'] + row['Female Population'] != row['Total Population']):
       print("Issue with number of males or females are row: ", row)
       print(i)
    elif(row['Number of Veterans'] > row['Total Population'] or row['Foreign-born'] > row['Total Population']):
       print("Issue with number of foreign born or number of veterans at row: ", row)
       print(i)
    i+=1
# Out:
# Issue with number of males or females are row:  City                            The Villages
# State                                Florida
# Median Age                              70.5
# Male Population                          NaN
# Female Population                        NaN
# Total Population                       72590
# Number of Veterans                     15231
# Foreign-born                            4034
# Average Household Size                   NaN
# State Code                                FL
# Race                      Hispanic or Latino
# Count                                   1066
# Name: 333, dtype: object
# 333
# Issue with number of males or females are row:  City                                   The Villages
# State                                       Florida
# Median Age                                     70.5
# Male Population                                 NaN
# Female Population                               NaN
# Total Population                              72590
# Number of Veterans                            15231
# Foreign-born                                   4034
# Average Household Size                          NaN
# State Code                                       FL
# Race                      Black or African-American
# Count                                           331
# Name: 449, dtype: object
# 449
# Issue with number of males or females are row:  City                      The Villages
# State                          Florida
# Median Age                        70.5
# Male Population                    NaN
# Female Population                  NaN
# Total Population                 72590
# Number of Veterans               15231
# Foreign-born                      4034
# Average Household Size             NaN
# State Code                          FL
# Race                             White
# Count                            72211
# Name: 1437, dtype: object
# 1437

# %% [markdown]
# It seems like there are three rows which contain number of Males and Females listed as NaN. Since there are so few rows with this issue, I decided that it is appropriate to remove those rows

# %%
drop_cols = ['Male Population', 'Female Population']

# %%
#drop those values in the Male Population and Female Population columns which contain NaNs
data_demo = data_demo.dropna(subset=drop_cols)

# %%
#run loop again to ensure drop worked
i=0
for index, row in data_demo.iterrows():
    if(row['Male Population'] + row['Female Population'] != row['Total Population']):
       print("Issue with number of males or females are row: ", row)
       print(i)
    elif(row['Number of Veterans'] > row['Total Population'] or row['Foreign-born'] > row['Total Population']):
       print("Issue with number of foreign born or number of veterans at row: ", row)
       print(i)
    i+=1

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# Map out the conceptual data model and explain why you chose that model

# %% [markdown]
# I chose to use a star schema with the immigration dataset chosen to be the fact table and the temperature dataset, airport codes, city demographics chosen to be dimension tables.

# %% [markdown]
# <h4>Fact Table</h4>

# %% [markdown]
# The fact table imm_fact is as shown below <br>
# cicid                 INTEGER <br>
# i94yr                 INTEGER<br>
# i94mon                INTEGER<br>
# i94cit                INTEGER<br>
# i94res                INTEGER<br>
# i94port               CHAR(3)<br>
# arrdate               INTEGER<br>
# i94mode               INTEGER<br>
# i94addr               CHAR(3)<br>
# depdate               INTEGER<br>
# i94bir                INTEGER<br>
# i94visa               INTEGER<br>
# count                 INTEGER<br>
# dtadfile              VARCHAR<br>
# visapost              CHAR(3)<br>
# entdepa               CHAR(1)<br>
# entdepd               CHAR(1)<br>
# matflag               CHAR(1)<br>
# biryear               INTEGER<br>
# dtaddto               INTEGER<br>
# gender                CHAR(1)<br>
# airline               CHAR(2)<br>
# admnum                INTEGER<br>
# fltno                 VARCHAR<br>
# visatype              VARCHAR<br>

# %% [markdown]
# <h4>Dimension Tables</h4>

# %% [markdown]
# The table <b>dim_country_origin</b> is shown below using the i94cit i94res columns from the immigration data dataset <br>
# country_code  INTEGER<br>
# country_name  VARCHAR

# %% [markdown]
# The dimension table <b>dim_destination</b> is shown below using the i94addr column from the immigration dataset <br>
# state_abb  CHAR(2)<br>
# #city VARCHAR - maybe not use this one

# %% [markdown]
# The dimension table <b>dim_visa_status</b> is shown below using the VISATYPE column<br>
# visa_type VARCHAR  <br>

# %% [markdown]
# The dimension table <b>dim_temp</b> is shown below using the city column from the temperature dataset<br>
# city VARCHAR  <br>
# Country  VARCHAR <br>
# monthly_avg_temp INTEGER

# %% [markdown]
# The dimension table <b>dim_demo_city</b> is shown below using the columns<br>
# city VARCHAR <br>
# state VARCHAR <br>
# number_of_veterans INTEGER <br>
# foreign_born INTEGER <br>
# race VARCHAR <br>
# count INTEGER

# %% [markdown]
# #### 3.2 Mapping Out Data Pipelines
# List the steps necessary to pipeline the data into the chosen data model

# %% [markdown]
# The table <b>dim_visa_status</b> can be created by utilizing insert statements as there is not a lot of variety. There are 17 different types of visas within the dataset

# %% [markdown]
# The table <b>dim_country_origin</b> table can be created by reading the code values from the i94cit i94res columns from the immigration dataset. Also, the description for each code has to be parsed to the country_name column.

# %% [markdown]
# The table <b>dim_destination</b> table can be created by reading the column i94addr

# %% [markdown]
# The table <b>dim_temp</b> can be created by reading the City, Country and AverageTemperature columns respectively from the temperature dataset.

# %% [markdown]
# The table <b>dim_demo_city</b> can be created from the us cities demographics dataset using the columns:<br>
# City <br>State<br> Number of Veterans<br> Foreign-born <br>Race<br> Count

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
#Build database connection
conn = psycopg2.connect(CONN_STRING)
conn.set_session(autocommit=True)
cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-04f048feb796> in <module>()
#       1 #Build database connection
# ----> 2 conn = psycopg2.connect(CONN_STRING)
#       3 conn.set_session(autocommit=True)
#       4 cur = conn.cursor()
#
# NameError: name 'CONN_STRING' is not defined

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
# Perform quality checks here

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.
